# %% [markdown]
# # Arbeidskrav 2 - Grunnleggende programmering med Python

# %%
"""
Arbeidskrav nr 2
Kamilla Lund Solumsmo (kasol8881@usn.no)
Oppdatert 2025 11 13

"""
# Out:
# '\nArbeidskrav nr 2\nKamilla Lund Solumsmo (kasol8881@usn.no)\nOppdatert 2025 11 13\n\n'

# %%
# Oppgave 1 - Beregning av alder

# Program som skal spoerre etter foedselsaar for deretter aa beregne alder i aar 2024.

foedselsaar = int(input("Hvilket år er du født?"))  # [Funksjon for å spørre bruker foedselsaar.]

ref_aar = 2024
alder_2024 = ref_aar - foedselsaar

print(f"Når du er født i {foedselsaar} vil du bli {alder_2024} år i 2024.")
# Out:
# Hvilket år er du født? 1990
# Når du er født i 1990 vil du bli 34 år i 2024.

# %%
# Oppgave 2 - Planlegge pizzainnkjoep

# Program for aa beregne antall pizza som skal kjoepes inn til klassefest
import numpy as np  # [Trenger numpy for aa bruke np.ceil()]

porsjon = 1/4   # [Antagelse om mengde pizza per pers]
antall_elever = int(input("Skriv inn antall elever: ")) # [Funksjon for å spørre bruker om antallet elever]

antall_pizza = np.ceil(antall_elever*porsjon)   # [Bruker np.ceil() for å runde opp antall pizzaer slik at det blir nok mat.]

print(f"Dersom det er {antall_elever} elever i klassen må det kjøpes inn {int(antall_pizza)} pizzaer.") # [Bruker int() for å fjerne desimalet slik at hele pizzaer kan kjoepes.]
# Out:
# Skriv inn antall elever:  31
# Dersom det er 31 elever i klassen må det kjøpes inn 8 pizzaer.

# %% [markdown]
# # Oppgave 3 - fra grader til radianer
#
# ## Progam som regner om fra grader til radianer
#
# ### Formel for omregning fra grader til radianer er gitt ved:
#
# $v_{rad} = v_{grad}*\frac{\pi}{180}$

# %%
"""Her kommer selve programkoden."""

import numpy as np  # [Trenger numpy pakken for aa bruke np.pi]

v_grad = float(input("Skriv inn gradtallet:" ))     # [Formel for at bruker skal sette et gradtall]

v_rad = v_grad*np.pi/180    # [Formel som beregner om fra grader til radianr]

print(f"{v_grad} grader er det samme som {v_rad:.3} radianer.")
# Out:
# Skriv inn gradtallet: 57
# 57.0 grader er det samme som 0.995 radianer.

# %%
# Oppgave 4 - Dictionary

# a - Opprette dictionary med land, hovedsteder og antall innbyggere:

data = {
    "Norge": ["Oslo", 0.634],
    "England": ["London", 8.982],
    "Frankrike": ["Paris", 2.161],
    "Italia": ["Roma", 2.873]
}

# %%
# 4b - printe resultat basert på brukerens input

land = str(input(("Hvilket land ønsker du info om?: ")))  # [Gjør om svaret til en tekststreng som kan leses ut av dictionaryen]

hovedstad = data[land][0]   # [Den foerste klammeparentesen henter hovedstaden, som igjen er foerste element i values som er gitt av en liste.]
innbyggere = data[land][1]  # [Det andre elementetet i listen er antall innbygere.]

print(f"{hovedstad} er hovedstaden i {land} og det er {innbyggere} mill. innbyggere i {hovedstad}")
# Out:
# Hvilket land ønsker du info om?:  England
# London er hovedstaden i England og det er 8.982 mill. innbyggere i London

# %%
# 4c - Utvide dictionary

nytt_land = str(input("Hvilket land ønsker du å legge til i dictionaryen?: "))  # [Spoer foerst etter landet, dette blir en tekststreng.]
ny_hovedstad = str(input(f"Hva er hovestaden i {nytt_land}? "))     # [Deretter hovedstad i dette landet, ogsaa en tekststreng.]
ny_innby = float(input(f"Hvor mange innbyggere er det i {ny_hovedstad}? Skriv svaret i millioner med punktum og 3 desimaler. ")) # [Til slutt antall innbyggere i millioner med tre desimaler, dette blir da et desimaltall.]

data[ny_hovedstad] = [ny_hovedstad, ny_innby]   # [Utvidere dictionaryen "Data" med det nye landet og tilhoerende fakta.]

print(f" Den oppdaterte dictionaryen er nå: \n {data}")
# Out:
# Hvilket land ønsker du å legge til i dictionaryen?:  Sverige
# Hva er hovestaden i Sverige?  Stockholm
# Hvor mange innbyggere er det i Stockholm? Skriv svaret i millioner med punktum og 3 desimaler.  3.542
#  Den oppdaterte dictionaryen er nå:
#  {'Norge': ['Oslo', 0.634], 'England': ['London', 8.982], 'Frankrike': ['Paris', 2.161], 'Italia': ['Roma', 2.873], 'Stockholm': ['Stockholm', 3.542]}

# %% [markdown]
# ### Oppgave 5 - areal og ytre omkrets av en figur
#
# ### I denne oppgavene trengs noen matematiske formler som vist under:
#
# ### Areal av en sirkel: $\pi*r^2$
# ### Omrets av en sirkel: $2\pi*r$
# ### Areal av en trekant: $\frac{g*h}{2}$
# ### Omkrets av en trekant: $a+b+x$, hvor x er hypotenusen
# ### Pytagoras: $hypotenus^2 = katet^2 + katet^2$, eller omskrevet som: $hypotenus = \sqrt{a^2 + b^2}$, hvor a og b er katetene.

# %%
import numpy as np      # [Trenger numpy for aa beregne kvadratrot]

a = float(input("Hvor lang skal diameteren og dermed den lille kateten i trekanten være? Oppgi tall i cm med 2 desimaler og . som desimaltegn: "))   # [Input funksjon for å definere stoerrelse som brukere oensker.]
b = float(input("Hvor lang skal den store kateten i trekanten være? Oppgi tall i cm med 2 desimaler og . som desimaltegn: "))   # [Input funksjon for å definere stoerelse som brukere oensker.]

# Trenger aa beregne hypotensusen i en trekant for å finne omkretsen. Figur viser at dette er en rettvinklet trekant og da gjelder Pytagoras:
x = np.sqrt(a**2+b**2)

""" Arealet av figuren bestaar av en halvsirkel og en rettvinklet trekant. Arealet av figuren vil være halvparten av arealet til sirkelen,
mens arealet av trekanten vil være gitt ved formelen over (grunnlinje*hoeyde)/2).
Omkretsen til halvsirkelen vil på samme måte være halvpraten omkretsen til en sirkel, mens omkretesen av trekanten vil være summen av den
store katet (b) og hypotenusen (x). Totalt areal og omkrets vil være summen av disse to figurene. """

areal_halvsirkel = (np.pi*a**2)/2
areal_trekant = (b*a)/2
areal_figur = areal_halvsirkel + areal_trekant

omkrets_halvsirkel = (2*np.pi*a)/2
omkrets_trekant = b + x
omkrets_figur = omkrets_halvsirkel + omkrets_trekant

print(f"Arealet av figuren, som består av diameter {a:.2f} cm, grunnlinje {b:.2f} cm og hypotenus {x:.2f} cm, er {areal_figur:.2f} cm\u00B2.")
print(f"Den ytre omkretsen av figuren, som består av diameter {a:.2f} cm, grunnlinje {b:.2f} cm og hypotenus {x:.2f} cm, er {omkrets_figur:.2f} cm.")
# Out:
# Hvor lang skal diameteren og dermed den lille kateten i trekanten være? Oppgi tall i cm med 2 desimaler og . som desimaltegn:  5.25
# Hvor lang skal den store kateten i trekanten være? Oppgi tall i cm med 2 desimaler:  8.32
# Arealet av figuren, som består av diameter 5.25 cm, grunnlinje 8.32 cm og hypotenus 9.84 cm, er 65.14 cm².
# Den ytre omkretsen av figuren, som består av diameter 5.25 cm, grunnlinje 8.32 cm og hypotenus 9.84 cm, er 34.65 cm.

# %% [markdown]
# ### Oppgave 6 - Funksjonsplott
#
# Funksjon $f(x) = -x^2 - 5$
# skal plottes for x i intervallet [-10, 10]

# %%
import numpy as np                  # [Trenger numpy for aa lage en array til x-aksen]
import matplotlib.pyplot as plt     #[Trenger denne pakken for aa lage et plot]

x = np.linspace(-10, 10, 200)   # [En array med punkter mellom -10 til 10 til x-aksen]
y = -x**2 - 5                   # [Funksjon av x som skal plottes paa y-aksen]

plt.plot(x, y, color="green", linestyle="dotted", label="$f(x) = (-x)^2 - 5$"),     # [Plot av funksjonen med diverse visuelle justeringer.]
plt.legend()
plt.title("Plot av funksjonen: $f(x) = (-x)^2 - 5$", fontweight = "bold")
plt.xlabel("x-akse")
plt.ylabel("y-akse")
plt.grid()
plt.show()
